% %% [markdown]
% 尝试调用自己的画图func

% %%
%%file my_triangle_plot.m
function y=my_triangle_plot(x)
    y=sin(x);
    plot(x,y,'p-')
    xlabel('X')
    ylabel('Y')
    title('Triangle-Func')
    grid on
% Out:
% Created file 'E:\09_sd\anaconda_py\jupyter_notebook_beginner_tuorial\mat_kf\my_triangle_plot.m'.

% %%
x=0:0.1:6*pi;
my_triangle_plot(x);
