% %% [markdown]
% # 函数调用
%
% * 函数调用
% * 函数指针（自定义函数作为参数传递）

% %%
%%file myplot.m
function y=myplot(method,x)
    y=method(x);
    plot(x,y,'p-')
    xlabel('X')
    ylabel('Y')
    title('Plot-Func')
    grid on

% %%
x=0:0.1:6*pi;
h=@sin;
myplot(h,x);

hold on;
h=@cos;
myplot(h,x);
